# %%
import optuna
import pickle 
from pathlib import Path

path = Path("./../../../data/deep_learning_data/Studies/TestStudy2/regression_study1.pkl")
study:optuna.study = pickle.load(open(path,"rb"))

# %%
best_trial = study.best_trial
print(f"Total number of trials {len(study.trials)}")
print(f"Best classification acc: {best_trial.value}")
for key, value in best_trial.params.items():
    print("{}: {}".format(key, value))
# Out:
# Total number of trials 190
# Best classification acc: 0.035293422639369965
# batch_size: 127
# n_layers: 1
# n_units_l0: 140
# dropout_l0: 0.009299938244271444
# optimizer: Adam
# lr: 0.0009484345459656315

# %%
df = study.trials_dataframe()
df.head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.106567 2022-05-10 11:53:40.240242 2022-05-10 11:54:13.597906
# 1       1  0.305513 2022-05-10 11:54:13.601052 2022-05-10 11:55:10.616168
# 2       2  0.087163 2022-05-10 11:55:10.618238 2022-05-10 11:55:52.113821
# 3       3  0.111515 2022-05-10 11:55:52.115913 2022-05-10 11:56:33.442804
# 4       4  0.165732 2022-05-10 11:56:33.444845 2022-05-10 11:57:50.811246
#
#                 duration  params_batch_size  params_dropout_l0  \
# 0 0 days 00:00:33.357664                212           0.300342
# 1 0 days 00:00:57.015116                 73           0.494064
# 2 0 days 00:00:41.495583                128           0.242527
# 3 0 days 00:00:41.326891                254           0.304018
# 4 0 days 00:01:17.366401                 57           0.481267
#
#    params_dropout_l1  params_dropout_l2  params_dropout_l3  params_dropout_l4  \
# ...

# %%
optuna.visualization.plot_intermediate_values(study)

# %%
optuna.visualization.plot_optimization_history(study)

# %%
optuna.visualization.plot_parallel_coordinate(study)

# %%
optuna.visualization.plot_param_importances(study)
